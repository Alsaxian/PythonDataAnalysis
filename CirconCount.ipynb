# %% [markdown]
# ## Circonscription count
# 26/09/2017
#
# Firstly we import Pandas and other relative libraries.

# %%
# If we are not using Jupyter Notebook, don't take into account the two following lines.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Make sure we have the pandas library previously installed.
import pandas as pd
import numpy as np

# %% [markdown]
# Then we load the csv file "Indicateurs statistiques 2013 sur les circonscriptions législatives".

# %%
df = pd.read_csv("indic-stat-2013-circonscriptions-legislatives.csv", skiprows = 6)
# To show some of the data frame
df.head(20)
df.tail(30)
# Out:
#    DEPCIR                                DEPCIR INTITULE  P13 pop  \
# 0    0101                     Ain  - 1re circonscription   115683
# 1    0102                      Ain  - 2e circonscription   129760
# 2    0103                      Ain  - 3e circonscription   131843
# 3    0104                      Ain  - 4e circonscription   126379
# 4    0105                      Ain  - 5e circonscription   115832
# 5    0201                    Aisne - 1re circonscription   105282
# 6    0202                     Aisne - 2e circonscription   108259
# 7    0203                     Aisne - 3e circonscription    96414
# 8    0204                     Aisne - 4e circonscription   113905
# 9    0205                     Aisne - 5e circonscription   116207
# 10   0301                  Allier  - 1re circonscription   120180
# 11   0302                   Allier  - 2e circonscription   115446
# 12   0303                   Allier  - 3e circonscription   107805
# 13   0401  Alpes de Haute-Provence - 1re circonscription    78975
# 14   0402   Alpes de Haute-Provence - 2e circonscription    82941
# 15   0501            Hautes-Alpes  - 1re circonscription    75300
# 16   0502             Hautes-Alpes  - 2e circonscription    63979
# 17   0601          Alpes-Maritimes - 1re circonscription   135455
# 18   0602           Alpes-Maritimes - 2e circonscription   115229
# 19   0603           Alpes-Maritimes - 3e circonscription   131096
#
#     P13 pop0002  P13 pop0305  P13 pop0610  P13 pop1117  P13 pop1824  \
# 0          2874         4429         7559        10511         8473
# 1          3326         5274         9193        13045        10288
# 2          3829         5895         9650        12389         8184
# 3          3093         4744         8663        12541         9392
# 4          3101         4760         8178        10608         7990
# 5          2769         4044         7098         9574         7963
# 6          2695         4150         6919         9948         8883
# 7          2437         3827         6356         9129         6969
# 8          2785         4053         7122        10243         9105
# 9          2983         4492         7773        11149         8164
# 10         2368         3662         6699         9959         7479
# 11         2226         3302         5943         8801         7734
# 12         2097         3183         5656         8089         7559
# 13         1545         2348         4543         6528         5106
# 14         1647         2646         4579         7052         5167
# 15         1562         2380         4371         6546         5134
# 16         1320         2142         3693         5451         3523
# 17         3102         4031         6235         9069        12860
# 18         2329         3859         7037        10544         7950
# 19         3174         4437         6851         9859        10867
#
#     P13 pop2539  P13 pop4054        ...         C13 F15P cs3  C13 F15P cs4  \
# 0         19970        24006        ...                 2316          7414
# 1         23323        29698        ...                 3884          9276
# 2         28579        30029        ...                 4581          9330
# 3         21763        27774        ...                 2372          8116
# 4         20959        24866        ...                 1985          6204
# 5         19210        21610        ...                 1623          5422
# 6         19034        21203        ...                 1703          5510
# 7         16144        19137        ...                  906          3514
# 8         19288        22980        ...                 1506          5812
# 9         20429        25475        ...                 1914          6141
# 10        18043        25151        ...                 1783          6317
# 11        16904        23027        ...                 1560          5198
# 12        15623        21053        ...                 1794          4997
# 13        11589        16490        ...                 1384          4486
# 14        12349        17208        ...                 1695          4904
# 15        11661        15876        ...                 1428          4492
# 16        10713        13832        ...                 1196          4067
# 17        25827        25296        ...                 4164          7805
# 18        18725        25045        ...                 3082          7400
# 19        23348        25527        ...                 4014          7912
#
#     C13 F15P cs5  C13 F15P cs6  C13 F15P cs7  C13 F15P cs8  P13 rp  C13 pmen  \
# 0          12157          2909         15219          7692   49795    112841
# 1          13217          3172         12564          9691   49833    126195
# 2          14138          2496         11375         11194   55531    129769
# 3          14168          3409         14585          7907   51484    122974
# 4          11031          5327         12946          8938   48553    113194
# 5          11661          2580         12641          9793   44169    102292
# 6          11249          2841         14498         10662   47015    106329
# 7           9253          2647         12787         10454   40226     94915
# 8          12073          2855         14570         11601   49548    111906
# 9          12999          3836         12893          8855   47467    114028
# 10         13099          2666         18563          8704   54953    116554
# 11         12838          2222         19586          9180   54729    111447
# 12         11492          2389         18605          8647   52087    105151
# 13          8307          1360         11644          6269   36661     77290
# 14          8198          1385         12161          6671   37872     80895
# 15          8283          1148         10699          5659   34538     73015
# 16          7242           753          8446          4279   29174     62061
# 17         15295          1695         19794         13597   70262    133376
# 18         11957          1849         14088          9826   48632    112412
# 19         13355          1318         18585         14093   61497    127911
#
#     C13 pmen menfam  C13 pmen menseul
# 0             93973             16784
# 1            111948             12264
# 2            108977             17972
# 3            106337             14690
# 4             95537             15472
# 5             85981             13978
# 6             88246             15802
# 7             80621             12343
# 8             93181             16534
# 9             98299             13436
# 10            93861             19947
# 11            87762             21307
# 12            81801             21089
# 13            61971             13449
# 14            65263             13533
# 15            58170             12982
# 16            50361             10453
# 17            93201             33872
# 18            94348             15349
# 19            98876             25225
#
# [20 rows x 57 columns]
#     DEPCIR                      DEPCIR INTITULE  P13 pop  P13 pop0002  \
# 526   9409   Val-de-Marne  - 9e circonscription   100596         3156
# 527   9410  Val-de-Marne  - 10e circonscription   128322         3935
# 528   9411  Val-de-Marne  - 11e circonscription   113591         3134
# 529   9501    Val-d’Oise  - 1re circonscription   124279         3460
# 530   9502     Val-d’Oise  - 2e circonscription   118654         3466
# 531   9503     Val-d’Oise  - 3e circonscription   137085         3924
# 532   9504     Val-d’Oise  - 4e circonscription   110954         3064
# 533   9505     Val-d’Oise  - 5e circonscription   134672         4911
# 534   9506     Val-d’Oise  - 6e circonscription   117824         3333
# 535   9507     Val-d’Oise  - 7e circonscription   116639         3551
# 536   9508     Val-d’Oise  - 8e circonscription   111720         3953
# 537   9509     Val-d’Oise  - 9e circonscription   114899         3499
# 538   9510    Val-d’Oise  - 10e circonscription   107955         3542
# 539  97101    Guadeloupe  - 1re circonscription   102005         2441
# 540  97102     Guadeloupe  - 2e circonscription   109221         2378
# 541  97103     Guadeloupe  - 3e circonscription   108719         2701
# 542  97104     Guadeloupe  - 4e circonscription    82174         1644
# 543  97201    Martinique  - 1re circonscription   104826         2279
# 544  97202     Martinique  - 2e circonscription    95123         1891
# 545  97203     Martinique  - 3e circonscription    84174         1907
# 546  97204     Martinique  - 4e circonscription   101428         2195
# 547  97301        Guyane  - 1re circonscription   116584         4888
# 548  97302         Guyane  - 2e circonscription   127534         6638
# 549  97401    La Réunion  - 1re circonscription   141410         4072
# 550  97402     La Réunion  - 2e circonscription   170621         4792
# 551  97403     La Réunion  - 3e circonscription    88030         2668
# 552  97404     La Réunion  - 4e circonscription   130598         3811
# 553  97405     La Réunion  - 5e circonscription    74042         2298
# 554  97406     La Réunion  - 6e circonscription   111544         3672
# 555  97407     La Réunion  - 7e circonscription   118858         3640
#
#      P13 pop0305  P13 pop0610  P13 pop1117  P13 pop1824  P13 pop2539  \
# 526         4335         6942         8330         8720        23493
# 527         5210         8283        10174        12469        31464
# 528         4601         7140         9222        12613        26157
# 529         5142         8756        11749        11140        24442
# 530         5110         7964        10845        11742        24275
# 531         6044         9728        13113        11701        26995
# 532         4585         7202         9928         9427        22064
# 533         6740         9905        12317        11912        30271
# 534         4867         7828        10471        10277        23502
# 535         5179         9013        11899        11112        22690
# 536         6067         9350        11983        11716        23456
# 537         5166         8901        11958        11275        22897
# 538         5337         8636        10555        11733        25484
# 539         3995         7196        10675         9523        15997
# 540         3939         7680        11587         8474        16883
# 541         4332         8170        12287         9138        17728
# 542         2789         5430         8539         6401        11354
# 543         3829         6842        10636         8634        16123
# 544         2969         5502         8908         7981        12998
# 545         2884         5271         7604         7089        13426
# 546         3522         6454        10143         7747        15187
# 547         7056        11935        15300        11867        24329
# 548         9789        16333        20648        14524        28614
# 549         6119        10373        14554        16575        27608
# 550         7686        13962        20766        16625        33780
# 551         3943         7324        10031         9099        16672
# 552         5807        10370        14955        12858        24985
# 553         3658         6484         9322         7629        13438
# 554         5779         9845        14019        12090        21943
# 555         5661        10197        14166        11361        22908
#
#      P13 pop4054        ...         C13 F15P cs3  C13 F15P cs4  C13 F15P cs5  \
# 526        20970        ...                 3783          6903         11538
# 527        26171        ...                 5402          9004         14638
# 528        22613        ...                 5745          8011         12166
# 529        26792        ...                 4287         10125         13303
# 530        24693        ...                 4925          9744         12068
# 531        29647        ...                 5643         11448         14176
# 532        23081        ...                 4933          8988         11520
# 533        27649        ...                 3617          8610         16132
# 534        24876        ...                 5821          9463         11889
# 535        23938        ...                 4226          8376         12526
# 536        21453        ...                 1291          5157         12957
# 537        24496        ...                 2378          8122         13519
# 538        21692        ...                 3946          8937         12565
# 539        22387        ...                 1182          5222         12204
# 540        26165        ...                 1867          6409         12025
# 541        26410        ...                 2546          7133         13229
# 542        18989        ...                 1255          4348          9208
# 543        25538        ...                 2013          6517         13394
# 544        22241        ...                 1739          5543         10664
# 545        18748        ...                 1967          5282         10409
# 546        25286        ...                 1900          6091         12124
# 547        22693        ...                 2525          6045         11243
# 548        20648        ...                 1108          3684          6761
# 549        30327        ...                 3479          8407         16653
# 550        38772        ...                 2965          8507         18804
# 551        19321        ...                  840          3627         10500
# 552        29383        ...                 1638          5972         15595
# 553        16440        ...                  560          2602          8321
# 554        24413        ...                 1167          4961         12772
# 555        26792        ...                 1623          5313         13665
#
#      C13 F15P cs6  C13 F15P cs7  C13 F15P cs8  P13 rp  C13 pmen  \
# 526          1750          8268          9551   41428     99278
# 527          2058         10616         12022   55500    125058
# 528          1392          9933         10662   48496    110563
# 529          2002         11008          9812   48268    121396
# 530          1524         10770          9767   46330    116399
# 531          1418         12833         10911   52039    133611
# 532          1102         12050          8891   44881    109237
# 533          2468          9915         13441   51203    132278
# 534          1267         11633         10174   48096    116587
# 535          1429         10441         10643   42428    114538
# 536          2519          7207         14297   36547    109639
# 537          2522          8826         10746   40674    113417
# 538          1524          5460         10004   38735    105820
# 539          1992         11079         13841   44818    101102
# 540          1460         10641         13330   45890    108804
# 541          1674          8880         12028   43947    107547
# 542          1346          9011         10602   35059     81483
# 543          2226         10371         11311   43627    103887
# 544          1978         11893         10255   40164     93717
# 545          1577          9736          9941   38144     82621
# 546          1528          9883         11588   42674     99800
# 547          1540          4531         17159   39377    114685
# 548           811          1459         24819   30079    126646
# 549          1745          9833         20147   59265    140095
# 550          2564          8684         25284   59622    169250
# 551          1141          6007         12536   33577     87566
# 552          1456          8508         18578   49185    128834
# 553          1266          4431         11225   25748     73463
# 554          1175          5072         18145   37505    109968
# 555          1797          7322         16378   41745    118271
#
#      C13 pmen menfam  C13 pmen menseul
# 526            80715             14370
# 527            96616             21446
# 528            86033             18426
# 529           104871             13331
# 530           100049             12699
# 531           117605             13406
# 532            93358             13546
# 533           113360             15120
# 534            98304             15353
# 535           100924             11066
# 536            96619              8605
# 537           101365              9906
# 538            93756              9461
# 539            80450             16473
# 540            89893             14953
# 541            91261             12993
# 542            66433             12043
# 543            87153             13715
# 544            76697             13348
# 545            64432             14891
# 546            82826             13977
# 547            98530              9862
# 548           105763              5296
# 549           114627             20457
# 550           151093             13289
# 551            76406              9000
# 552           112337             12669
# 553            66033              5565
# 554            99953              7328
# 555           105954              9001
#
# [30 rows x 57 columns]

# %%
# Is there any missing value in the data frame?
# Answer: no. So we are fine.
df.isnull().values.any()

# What are the numbers of rows and columns?
df.shape
# What are the data types of the columns?
df.dtypes
# What do we have in column 'DECIR'?
df['DEPCIR']
# Out:
# False
# (556, 57)
# DEPCIR              object
# DEPCIR INTITULE     object
# P13 pop              int64
# P13 pop0002          int64
# P13 pop0305          int64
# P13 pop0610          int64
# P13 pop1117          int64
# P13 pop1824          int64
# P13 pop2539          int64
# P13 pop4054          int64
# P13 pop5564          int64
# P13 pop6579          int64
# P13 pop80p           int64
# P13 pop0019          int64
# P13 pop2064          int64
# P13 pop65P           int64
# P13 poph             int64
# P13 h0019            int64
# P13 h2064            int64
# P13 h65p             int64
# P13 popf             int64
# P13 f0019            int64
# P13 f2064            int64
# P13 f65p             int64
# P13 pop fr           int64
# P13 pop etr          int64
# P13 Pop15P           int64
# C13 Pop15P cs1       int64
# C13 Pop15P cs2       int64
# C13 Pop15P cs3       int64
# C13 Pop15P cs4       int64
# C13 Pop15P cs5       int64
# C13 Pop15P cs6       int64
# C13 Pop15P cs7       int64
# C13 Pop15P cs8       int64
# C13 H15P             int64
# C13 H15P cs1         int64
# C13 H15P cs2         int64
# C13 H15P cs3         int64
# C13 H15P cs4         int64
# C13 H15P cs5         int64
# C13 H15P cs6         int64
# C13 H15P cs7         int64
# C13 H15P cs8         int64
# C13 F15P             int64
# C13 F15P cs1         int64
# C13 F15P cs2         int64
# C13 F15P cs3         int64
# C13 F15P cs4         int64
# C13 F15P cs5         int64
# C13 F15P cs6         int64
# C13 F15P cs7         int64
# C13 F15P cs8         int64
# P13 rp               int64
# C13 pmen             int64
# C13 pmen menfam      int64
# C13 pmen menseul     int64
# dtype: object
# 0       0101
# 1       0102
# 2       0103
# 3       0104
# 4       0105
# 5       0201
# 6       0202
# 7       0203
# 8       0204
# 9       0205
# 10      0301
# 11      0302
# 12      0303
# 13      0401
# 14      0402
# 15      0501
# 16      0502
# 17      0601
# 18      0602
# 19      0603
# 20      0604
# 21      0605
# 22      0606
# 23      0607
# 24      0608
# 25      0609
# 26      0701
# 27      0702
# 28      0703
# 29      0801
#        ...
# 526     9409
# 527     9410
# 528     9411
# 529     9501
# 530     9502
# 531     9503
# 532     9504
# 533     9505
# 534     9506
# 535     9507
# 536     9508
# 537     9509
# 538     9510
# 539    97101
# 540    97102
# 541    97103
# 542    97104
# 543    97201
# 544    97202
# 545    97203
# 546    97204
# 547    97301
# 548    97302
# 549    97401
# 550    97402
# 551    97403
# 552    97404
# 553    97405
# 554    97406
# 555    97407
# Name: DEPCIR, Length: 556, dtype: object

# %% [markdown]
# Now we can extract the department name, which situates always before a space concatenated by a '-', with the string method ```partition()```.
#
# Attention: a space alone as separator won't work correctly because of i.g. "La réunion". A '-' alone won't work either because of
# i.g. "Alpes-Maritimes". The separator ' -' is the minimum which will work.
#
# Then we add it as a new column to the data set.

# %%
df['nomDepartement'] = df['DEPCIR INTITULE'].apply(func = lambda x: x.partition(' -')[0].strip()) 
# use strip() to get rid of the problem that the entries have different numbers of spaces around the '-' sign.

df['nomDepartement']
df['nomDepartement'][1]

# Which type does the department id have ?
type(df.iloc[1, 0])
# Out:
# 0                          Ain
# 1                          Ain
# 2                          Ain
# 3                          Ain
# 4                          Ain
# 5                        Aisne
# 6                        Aisne
# 7                        Aisne
# 8                        Aisne
# 9                        Aisne
# 10                      Allier
# 11                      Allier
# 12                      Allier
# 13     Alpes de Haute-Provence
# 14     Alpes de Haute-Provence
# 15                Hautes-Alpes
# 16                Hautes-Alpes
# 17             Alpes-Maritimes
# 18             Alpes-Maritimes
# 19             Alpes-Maritimes
# 20             Alpes-Maritimes
# 21             Alpes-Maritimes
# 22             Alpes-Maritimes
# 23             Alpes-Maritimes
# 24             Alpes-Maritimes
# 25             Alpes-Maritimes
# 26                     Ardèche
# 27                     Ardèche
# 28                     Ardèche
# 29                    Ardennes
#                 ...
# 526               Val-de-Marne
# 527               Val-de-Marne
# 528               Val-de-Marne
# 529                 Val-d’Oise
# 530                 Val-d’Oise
# 531                 Val-d’Oise
# 532                 Val-d’Oise
# 533                 Val-d’Oise
# 534                 Val-d’Oise
# 535                 Val-d’Oise
# 536                 Val-d’Oise
# 537                 Val-d’Oise
# 538                 Val-d’Oise
# 539                 Guadeloupe
# 540                 Guadeloupe
# 541                 Guadeloupe
# 542                 Guadeloupe
# 543                 Martinique
# 544                 Martinique
# 545                 Martinique
# 546                 Martinique
# 547                     Guyane
# 548                     Guyane
# 549                 La Réunion
# 550                 La Réunion
# 551                 La Réunion
# 552                 La Réunion
# 553                 La Réunion
# 554                 La Réunion
# 555                 La Réunion
# Name: nomDepartement, Length: 556, dtype: object
# 'Ain'
# str

# %% [markdown]
# Now let's define what we want to do to each column that will be later kept in our final data frame, with a dictionary structure like ```{column : action}```.
# We actually want to count the circonscription number of a department, keep its name and add up the circonscription populations of the same department for all the rest of the data frame.

# %%
myKwargs = {k:sum for k in df.columns.values[2:]}
myKwargs.update({'DEPCIR INTITULE' : len, "nomDepartement" : max})
myKwargs
# Out:
# {'C13 F15P': <function sum>,
#  'C13 F15P cs1': <function sum>,
#  'C13 F15P cs2': <function sum>,
#  'C13 F15P cs3': <function sum>,
#  'C13 F15P cs4': <function sum>,
#  'C13 F15P cs5': <function sum>,
#  'C13 F15P cs6': <function sum>,
#  'C13 F15P cs7': <function sum>,
#  'C13 F15P cs8': <function sum>,
#  'C13 H15P': <function sum>,
#  'C13 H15P cs1': <function sum>,
#  'C13 H15P cs2': <function sum>,
#  'C13 H15P cs3': <function sum>,
#  'C13 H15P cs4': <function sum>,
#  'C13 H15P cs5': <function sum>,
#  'C13 H15P cs6': <function sum>,
#  'C13 H15P cs7': <function sum>,
#  'C13 H15P cs8': <function sum>,
#  'C13 Pop15P cs1': <function sum>,
#  'C13 Pop15P cs2': <function sum>,
#  'C13 Pop15P cs3': <function sum>,
#  'C13 Pop15P cs4': <function sum>,
#  'C13 Pop15P cs5': <function sum>,
#  'C13 Pop15P cs6': <function sum>,
#  'C13 Pop15P cs7': <function sum>,
#  'C13 Pop15P cs8': <function sum>,
#  'C13 pmen': <function sum>,
#  'C13 pmen menfam': <function sum>,
#  'C13 pmen menseul': <function sum>,
#  'DEPCIR INTITULE': <function len>,
#  'P13 Pop15P': <function sum>,
#  'P13 f0019': <function sum>,
#  'P13 f2064': <function sum>,
#  'P13 f65p': <function sum>,
#  'P13 h0019': <function sum>,
#  'P13 h2064': <function sum>,
#  'P13 h65p': <function sum>,
#  'P13 pop': <function sum>,
#  'P13 pop etr': <function sum>,
#  'P13 pop fr': <function sum>,
#  'P13 pop0002': <function sum>,
#  'P13 pop0019': <function sum>,
#  'P13 pop0305': <function sum>,
#  'P13 pop0610': <function sum>,
#  'P13 pop1117': <function sum>,
#  'P13 pop1824': <function sum>,
#  'P13 pop2064': <function sum>,
#  'P13 pop2539': <function sum>,
#  'P13 pop4054': <function sum>,
#  'P13 pop5564': <function sum>,
#  'P13 pop6579': <function sum>,
#  'P13 pop65P': <function sum>,
#  'P13 pop80p': <function sum>,
#  'P13 popf': <function sum>,
#  'P13 poph': <function sum>,
#  'P13 rp': <function sum>,
#  'nomDepartement': <function max>}

# %% [markdown]
# Now that we have our goal action associated to each column, we simply aggregate the lines by their department, before we feed to the ```groupby()``` function our action dictionary with a ```agg()``` method.

# %%
dfFinal = df.groupby(df['DEPCIR'].map(lambda No: No[:2] if len(No) == 4 else No[:3]), as_index = True).agg(myKwargs)

# The following three lines are my first tries. No need to read them.
# df.groupby(df['DEPCIR'].map(lambda No: No[:2] if len(No) == 4 else No[:3])).agg(myKwargs)[['DEPCIR INTITULE', "nomDepartement"]] 
# map(int, df['DEPCIR']) # Doesn't work! Cause there are ids like '2A01'...
# df['DEPCIR'].map(lambda No: No[:2])

# The following command can "lift" the groupby factor to a normal column.
dfFinal.reset_index(inplace=True)

# We can chnge the names of the columns.
dfFinal.columns.values[[0, -1]] = ['DepartID', 'nombreCircons']

# Now we put the columns in a more friendly order.
namesInOrder = list(dfFinal.columns.values)
namesInOrder = [namesInOrder[0]] + namesInOrder[-2:] + namesInOrder[1:-2]

# Let's see what our result looks like.
dfFinal1 = dfFinal[namesInOrder]
dfFinal1
# Out:
#    DepartID           nomDepartement  nombreCircons  P13 pop  P13 pop0002  \
# 0        01                      Ain              5   619497        16223
# 1        02                    Aisne              5   540067        13669
# 2        03                   Allier              3   343431         6691
# 3        04  Alpes de Haute-Provence              2   161916         3192
# 4        05             Hautes-Alpes              2   139279         2882
# 5        06          Alpes-Maritimes              9  1080771        22964
# 6        07                  Ardèche              3   320379         6748
# 7        08                 Ardennes              3   280907         6597
# 8        09                   Ariège              2   152684         2981
# 9        10                     Aube              3   306581         7215
# 10       11                     Aude              3   364877         7571
# 11       12                  Aveyron              3   277740         5422
# 12       13         Bouches-du-Rhône             16  1993177        47810
# 13       14                 Calvados              6   689945        15546
# 14       15                   Cantal              2   147035         2622
# 15       16                 Charente              3   353482         7051
# 16       17        Charente-Maritime              5   633417        12174
# 17       18                     Cher              3   311650         6372
# 18       19                  Corrèze              2   240781         4363
# 19       21                Côte-d’Or              5   529761        11796
# 20       22            Côtes-d’Armor              5   597085        12572
# 21       23                   Creuse              1   120872         1936
# 22       24                 Dordogne              4   416909         7418
# 23       25                    Doubs              5   533320        13528
# 24       26                    Drôme              4   494712        11974
# 25       27                     Eure              5   595043        15436
# 26       28             Eure-et-Loir              4   432967        11073
# 27       29                Finistère              8   903921        19242
# 28       2A             Corse-du-Sud              2   149234         2927
# 29       2B              Haute-Corse              2   170974         3551
# ..      ...                      ...            ...      ...          ...
# 70       70              Haute-Saône              2   238956         5416
# 71       71           Saône-et-Loire              5   556222        11642
# 72       72                   Sarthe              5   569035        13934
# 73       73                   Savoie              4   423715         9703
# 74       74             Haute-Savoie              6   769677        20155
# 75       75                    Paris             18  2229622        49708
# 76       76           Seine-Maritime             10  1254609        30912
# 77       77           Seine-et-Marne             11  1365200        38738
# 78       78                 Yvelines             12  1418484        38594
# 79       79              Deux-Sèvres              3   371632         8303
# 80       80                    Somme              5   571675        13692
# 81       81                     Tarn              3   381927         7820
# 82       82          Tarn-et-Garonne              2   250342         5951
# 83       83                      Var              8  1028583        20768
# 84       84                 Vaucluse              5   549949        13138
# 85       85                   Vendée              5   655506        15229
# 86       86                   Vienne              4   431248         9806
# 87       87             Haute-Vienne              3   375856         7990
# 88       88                   Vosges              4   375226         7862
# 89       89                    Yonne              3   341483         7668
# 90       90    Territoire-de-Belfort              2   144318         3656
# 91       91                  Essonne             10  1253931        35644
# 92       92           Hauts-de-Seine             13  1591403        47230
# 93       93        Seine-Saint-Denis             12  1552482        52817
# 94       94             Val-de-Marne             11  1354006        38923
# 95       95               Val-d’Oise             10  1194681        36703
# 96      971               Guadeloupe              4   402119         9164
# 97      972               Martinique              4   385551         8272
# 98      973                   Guyane              2   244118        11526
# 99      974               La Réunion              7   835103        24953
#
#     P13 pop0305  P13 pop0610  P13 pop1117  P13 pop1824  P13 pop2539  \
# 0         25102        43243        59094        44327       114594
# 1         20566        35268        50043        41084        94105
# 2         10147        18298        26849        22772        50570
# 3          4994         9122        13580        10273        23938
# 4          4522         8064        11997         8657        22374
# 5         33724        56315        81924        83277       184630
# 6         10641        19123        27534        19842        49380
# 7         10228        17789        25332        20534        48166
# 8          4882         8455        12195         9296        23022
# 9         11552        19157        25982        24665        52857
# 10        12152        20790        30345        23891        55755
# 11         8365        15039        21461        16630        41138
# 12        71826       119160       166694       177764       364976
# 13        24393        42411        60115        62691       119577
# 14         3940         7488        10406         8567        21590
# 15        11033        19269        28182        23642        55422
# 16        19157        33762        50006        44092        95218
# 17         9931        17209        25121        21186        47918
# 18         6907        12484        17861        15995        36061
# 19        17402        30371        43442        51856        95725
# 20        20469        36013        50870        38870        89704
# 21         3127         5761         8587         6938        15890
# 22        11584        21589        32022        24532        58474
# 23        20543        33416        45207        49084       101449
# 24        18446        31558        43970        35359        82924
# 25        24127        41037        56488        42770       106851
# 26        17184        29208        39700        30305        76544
# 27        30450        53261        76591        69559       150216
# 28         4591         7501        11360        10019        26801
# 29         5317         8806        12416        13113        31076
# ..          ...          ...          ...          ...          ...
# 70         8481        14953        20921        15513        39365
# 71        18009        31776        45362        35957        86231
# 72        21272        36683        51376        44228        95358
# 73        15096        25716        36839        32456        76338
# 74        30157        50396        68170        56336       157615
# 75        66713       104223       140094       217737       591521
# 76        46433        77847       109728       114316       227862
# 77        59045        98935       134099       119373       273671
# 78        58222        98709       135616       119819       269938
# 79        12968        22848        32087        23802        60474
# 80        20587        35342        49568        54013       103238
# 81        12546        21918        31540        26342        57987
# 82         9316        16063        22028        16030        42073
# 83        31816        55362        81271        72698       164328
# 84        19767        33340        48055        42089        92276
# 85        24128        42075        55894        42466       109427
# 86        14843        24949        34568        41172        74823
# 87        11831        20340        27862        31797        61788
# 88        12222        21827        32560        27190        60166
# 89        11900        20799        29594        21700        55156
# 90         5473         9214        12287        13090        27458
# 91        54373        88368       117816       113404       251038
# 92        66123       103151       130819       132493       366623
# 93        75960       117762       142560       143635       349809
# 94        56146        88590       115589       121546       295543
# 95        54237        87283       114818       112035       246076
# 96        15055        28476        43088        33536        61962
# 97        13204        24069        37291        31451        57734
# 98        16845        28268        35948        26391        52943
# 99        38653        68555        97813        86237       161334
#
#           ...         C13 F15P cs3  C13 F15P cs4  C13 F15P cs5  C13 F15P cs6  \
# 0         ...                15138         40340         64711         17313
# 1         ...                 7652         26399         57235         14759
# 2         ...                 5137         16512         37429          7277
# 3         ...                 3079          9390         16505          2745
# 4         ...                 2624          8559         15525          1901
# 5         ...                31846         66266        115779         13565
# 6         ...                 5412         18094         32532          7315
# 7         ...                 3622         13261         29834          6596
# 8         ...                 2328          8310         16025          2332
# 9         ...                 5359         15527         31124          9447
# 10        ...                 6024         19022         37851          5514
# 11        ...                 4371         14689         28341          5073
# 12        ...                61304        125272        197617         26614
# 13        ...                15806         40169         75234         14561
# 14        ...                 2163          7008         15760          2977
# 15        ...                 5967         18509         37089          9871
# 16        ...                11494         33406         68101         12532
# 17        ...                 4994         15750         33707          7737
# 18        ...                 3957         12856         25306          5323
# 19        ...                14777         34635         55364         11790
# 20        ...                10136         30231         58705         15112
# 21        ...                 1858          5538         12700          1713
# 22        ...                 6010         20445         44511          9712
# 23        ...                12319         31581         51915         18908
# 24        ...                10519         29633         49324         12471
# 25        ...                11733         34154         63577         18889
# 26        ...                 8768         26467         46856         11799
# 27        ...                18773         51707         91359         21044
# 28        ...                 2984          8090         17741          1666
# 29        ...                 3210          7830         18052          1688
# ..        ...                  ...           ...           ...           ...
# 70        ...                 3680         13008         25290          7230
# 71        ...                 8586         29058         58520         14642
# 72        ...                10241         29997         61020         17205
# 73        ...                10560         28408         45962          8041
# 74        ...                21223         56998         85491         18599
# 75        ...               251290        163171        162338         20198
# 76        ...                26924         74220        137987         27144
# 77        ...                42989        102447        156688         23378
# 78        ...                80434        107392        126678         14744
# 79        ...                 7224         20385         38911         10739
# 80        ...                11169         30892         58765         15420
# 81        ...                 7217         21745         39497          6361
# 82        ...                 4176         13280         26139          5642
# 83        ...                20164         56997        108541         12707
# 84        ...                11452         30144         57213         11525
# 85        ...                 8878         33924         69662         21776
# 86        ...                10370         25151         47049          8956
# 87        ...                 8760         23060         37945          7298
# 88        ...                 5661         18612         39811         11101
# 89        ...                 5568         18348         36402          8752
# 90        ...                 3087          8516         14179          3928
# 91        ...                52035         96494        127545         17065
# 92        ...               135947        119612        136824         12706
# 93        ...                42547         92503        178177         29944
# 94        ...                69841        101067        141017         17003
# 95        ...                41067         88970        130655         17775
# 96        ...                 6850         23112         46666          6472
# 97        ...                 7619         23433         46591          7309
# 98        ...                 3633          9729         18004          2351
# 99        ...                12272         39389         96310         11144
#
#     C13 F15P cs7  C13 F15P cs8   P13 rp  C13 pmen  C13 pmen menfam  \
# 0          66689         45422   255196    604973           516772
# 1          67389         51365   228425    529470           446328
# 2          56754         26531   161769    333152           263424
# 3          23805         12940    74533    158185           127234
# 4          19145          9938    63712    135076           108531
# 5         153945         96870   503767   1056212           827644
# 6          47381         22907   140800    311229           257175
# 7          34832         28713   122261    275882           229592
# 8          23533         11752    69791    148461           119559
# 9          42166         24849   136694    298980           243822
# 10         54383         32445   164502    356714           291184
# 11         45941         17569   126513    269023           218488
# 12        229177        219333   867209   1941130          1573313
# 13         92824         54453   303280    672361           548833
# 14         25351          9142    68139    142298           114407
# 15         54029         25787   161038    344148           280625
# 16        101809         46648   293969    618346           499271
# 17         48211         22938   142255    302728           245556
# 18         40681         15766   111346    232309           185871
# 19         67446         42717   240598    514080           409798
# 20         97604         39451   269399    582420           474439
# 21         22567          7530    57442    116737            91300
# 22         71476         28203   191413    404883           328716
# 23         62084         44809   236761    521694           423033
# 24         64870         38774   215651    484966           401668
# 25         70281         43809   244943    582922           499655
# 26         53737         30073   180508    423540           360775
# 27        130313         68943   414689    879912           699929
# 28         17467         16441    63827    146881           121354
# 29         19665         21873    75149    166811           134312
# ..           ...           ...      ...       ...              ...
# 70         31671         18165   104331    233684           195510
# 71         84657         41638   251533    542140           443522
# 72         77816         39705   247586    554633           461787
# 73         50878         32120   188372    414626           337592
# 74         77712         54781   333141    756490           627090
# 75        206261        209135  1153814   2182650          1457612
# 76        155995        112688   550381   1229900          1011988
# 77        119527        108530   527428   1340107          1168597
# 78        134109        121702   561331   1390427          1196662
# 79         53121         23723   163276    362148           303297
# 80         70586         54299   243432    559090           466596
# 81         57698         30548   169401    371790           307548
# 82         34161         19372   106015    244062           205715
# 83        150115         96044   462887   1002854           817314
# 84         68887         53866   238835    538739           445462
# 85         95909         39713   283057    638981           540471
# 86         58347         34238   197598    419172           334735
# 87         57622         29359   178464    367322           288314
# 88         55109         28981   167591    365700           300099
# 89         50001         24553   150414    330979           271913
# 90         16334         13504    64217    140862           114409
# 91        116202        102371   489170   1223167          1054412
# 92        143400        130655   700622   1563250          1238781
# 93        113207        163193   593577   1521605          1271450
# 94        126290        116539   566569   1328834          1080754
# 95        100143        108686   449201   1172922          1020211
# 96         39611         49801   169714    398936           328037
# 97         41883         43095   164609    380025           311108
# 98          5990         41978    69456    241331           204293
# 99         49857        122293   306647    827447           726403
#
#     C13 pmen menseul
# 0              77182
# 1              72093
# 2              62343
# 3              26982
# 4              23435
# 5             195930
# 6              46830
# 7              40830
# 8              24863
# 9              48876
# 10             56217
# 11             44328
# 12            305624
# 13            105740
# 14             24614
# 15             55216
# 16            103455
# 17             51151
# 18             40821
# 19             90605
# 20             96114
# 21             22059
# 22             65480
# 23             85775
# 24             72361
# 25             70862
# 26             54685
# 27            159689
# 28             18434
# 29             24860
# ..               ...
# 70             33837
# 71             88505
# 72             82836
# 73             66460
# 74            111112
# 75            586156
# 76            189713
# 77            142378
# 78            164450
# 79             52142
# 80             77241
# 81             55808
# 82             32542
# 83            159063
# 84             79164
# 85             87530
# 86             72816
# 87             69668
# 88             58523
# 89             51807
# 90             23521
# 91            139606
# 92            271149
# 93            188357
# 94            198236
# 95            122493
# 96             56462
# 97             55931
# 98             15158
# 99             77309
#
# [100 rows x 58 columns]
